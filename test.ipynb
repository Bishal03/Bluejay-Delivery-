# %%
import pandas as pd

def load_data(file_path):
    df = pd.read_excel(file_path)
    return df

def analyze_consecutive_days(df):
    # Convert 'Time Out' to datetime
    df['Time Out'] = pd.to_datetime(df['Time Out'])

    # Calculate the day difference within each employee group
    df['Day Difference'] = df.groupby('Employee Name')['Time Out'].diff().dt.days.fillna(0)

    # Identify consecutive days
    consecutive_days = df[df['Day Difference'] == 1]

    for _, row in consecutive_days.iterrows():
        print(f"Employee: {row['Employee Name']}, Position ID: {row['Position ID']} worked for 7 consecutive days.")

def analyze_shift_gaps(df):
    # Convert 'Time Out' to datetime
    df['Time Out'] = pd.to_datetime(df['Time Out'])
    
    # Convert 'Timecard Hours (as Time)' to numeric, ignoring errors (coercing non-numeric values to NaN)
    df['Timecard Hours (as Time)'] = pd.to_numeric(df['Timecard Hours (as Time)'], errors='coerce')

    # Calculate the shift gap within each employee group
    df['Shift Gap'] = df.groupby('Employee Name')['Time Out'].diff().dt.total_seconds() / 3600 - df['Timecard Hours (as Time)'].shift()

    # Identify shift gaps between 1 and 10 hours
    shift_gaps = df[(df['Shift Gap'] > 1) & (df['Shift Gap'] < 10)]

    for _, row in shift_gaps.iterrows():
        print(f"Employee: {row['Employee Name']}, Position ID: {row['Position ID']} has a shift gap between shifts of {row['Shift Gap']} hours.")

def analyze_long_shifts(df):
    # Identify shifts longer than 14 hours
    long_shifts = df[df['Timecard Hours (as Time)'] > 14]

    for _, row in long_shifts.iterrows():
        print(f"Employee: {row['Employee Name']}, Position ID: {row['Position ID']} worked for more than 14 hours in a single shift.")

def main(file_path):
    data = load_data(file_path)
    analyze_consecutive_days(data)
    analyze_shift_gaps(data)
    analyze_long_shifts(data)

if __name__ == "__main__":
    file_path = "C:/Users/bisha/Downloads/Assignment_Timecard.xlsx"
    main(file_path)
# Out:
# Employee: Arias, FeXipe, Position ID: WFS000170 worked for 7 consecutive days.
# Employee: GarWes, JAsMiW, Position ID: WFS000181 worked for 7 consecutive days.
# Employee: FeXix, XeEWeX, Position ID: WFS000183 worked for 7 consecutive days.
# Employee: Xee, XaCar, Position ID: WFS000200 worked for 7 consecutive days.
# Employee: MAake, CasiaWE, Position ID: WFS000228 worked for 7 consecutive days.
# Employee: MAake, CasiaWE, Position ID: WFS000228 worked for 7 consecutive days.
# Employee: MAake, CasiaWE, Position ID: WFS000228 worked for 7 consecutive days.
# Employee: DiWh, DaA, Position ID: WFS000268 worked for 7 consecutive days.
# Employee: DiWh, DaA, Position ID: WFS000268 worked for 7 consecutive days.
# Employee: DiWh, DaA, Position ID: WFS000268 worked for 7 consecutive days.
# Employee: REdrigAez, PedrE, Position ID: WFS000336 worked for 7 consecutive days.
# Employee: MraW, WiXXiaC Ha, Position ID: WFS000345 worked for 7 consecutive days.
# Employee: CaMXEck, CEhaCCed, Position ID: WFS000362 worked for 7 consecutive days.
# Employee: MaXeGi, ACirCasEAd, Position ID: WFS000364 worked for 7 consecutive days.
# Employee: PayaW, DaWieX, Position ID: WFS000368 worked for 7 consecutive days.
# Employee: ErEpeza, JEvaW, Position ID: WFS000382 worked for 7 consecutive days.
# Employee: VasqAez, AXfredE, Position ID: WFS000391 worked for 7 consecutive days.
# Employee: SavaWg, JEhW, Position ID: WFS000393 worked for 7 consecutive days.
# Employee: REdrigAez, XAis, Position ID: WFS000412 worked for 7 consecutive days.
# Employee: SiWgh, CaWpreeM, Position ID: WFS000418 worked for 7 consecutive days.
# Employee: SiWgh, JaspreeM, Position ID: WFS000424 worked for 7 consecutive days.
# Employee: SiWgh, JaspreeM, Position ID: WFS000424 worked for 7 consecutive days.
# Employee: SiWgXeMEW, REger, Position ID: WFS000426 worked for 7 consecutive days.
# Employee: PaXaciE, JEWaMhaW, Position ID: WFS000434 worked for 7 consecutive days.
# Employee: ErEzcE, SaAX, Position ID: WFS000442 worked for 7 consecutive days.
# Employee: ErEzcE, SaAX, Position ID: WFS000442 worked for 7 consecutive days.
# Employee: CercadE, SaAX, Position ID: WFS000446 worked for 7 consecutive days.
# Employee: CercadE, SaAX, Position ID: WFS000446 worked for 7 consecutive days.
# Employee: CercadE, SaAX, Position ID: WFS000446 worked for 7 consecutive days.
# Employee: CercadE, SaAX, Position ID: WFS000446 worked for 7 consecutive days.
# Employee: CEreira Jr, JEse, Position ID: WFS000456 worked for 7 consecutive days.
# Employee: AXvarez, Edgar, Position ID: WFS000457 worked for 7 consecutive days.
# Employee: PaAXE, KyXe, Position ID: WFS000460 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: XiWW, JAsMiW, Position ID: WFS000462 worked for 7 consecutive days.
# Employee: CaXdEWadE, AXfEWsE, Position ID: WFS000463 worked for 7 consecutive days.
# Employee: CaXdEWadE, AXfEWsE, Position ID: WFS000463 worked for 7 consecutive days.
# Employee: CaXdEWadE, AXfEWsE, Position ID: WFS000463 worked for 7 consecutive days.
# Employee: PerkiWs, MarraWce, Position ID: WFS000469 worked for 7 consecutive days.
# Employee: PerkiWs, MarraWce, Position ID: WFS000469 worked for 7 consecutive days.
# Employee: PerkiWs, MarraWce, Position ID: WFS000469 worked for 7 consecutive days.
# Employee: GAeWdia, JAaW CarXEs, Position ID: WFS000473 worked for 7 consecutive days.
# Employee: ZaCEra, Edward, Position ID: WFS000477 worked for 7 consecutive days.
# Employee: ZaCEra, Edward, Position ID: WFS000477 worked for 7 consecutive days.
# Employee: ZaCEra, Edward, Position ID: WFS000477 worked for 7 consecutive days.
# Employee: ZaCEra, Edward, Position ID: WFS000477 worked for 7 consecutive days.
# Employee: ArevaXE, JEse, Position ID: WFS000491 worked for 7 consecutive days.
# Employee: ArevaXE, JEse, Position ID: WFS000491 worked for 7 consecutive days.
# Employee: ArevaXE, JEse, Position ID: WFS000491 worked for 7 consecutive days.
# Employee: CErMes, DEAgXas Farid, Position ID: WFS000495 worked for 7 consecutive days.
# Employee: CercadE, CrisMiaW, Position ID: WFS000496 worked for 7 consecutive days.
# Employee: CercadE, CrisMiaW, Position ID: WFS000496 worked for 7 consecutive days.
# Employee: Caxies, MerreXX, Position ID: WFS000500 worked for 7 consecutive days.
# Employee: Caxies, MerreXX, Position ID: WFS000500 worked for 7 consecutive days.
# Employee: CEMMa, Jessica, Position ID: WFS000503 worked for 7 consecutive days.
# Employee: CEMMa, Jessica, Position ID: WFS000503 worked for 7 consecutive days.
# Employee: Rivera AXcaWMar, GrayaW, Position ID: WFS000507 worked for 7 consecutive days.
# Employee: EXivares, FeXCaW, Position ID: WFS000508 worked for 7 consecutive days.
# Employee: EXivares, FeXCaW, Position ID: WFS000508 worked for 7 consecutive days.
# Employee: EXivares, FeXCaW, Position ID: WFS000508 worked for 7 consecutive days.
# Employee: ChaCErE, HEXger CarMiWez, Position ID: WFS000509 worked for 7 consecutive days.
# Employee: ChaCErE, HEXger CarMiWez, Position ID: WFS000509 worked for 7 consecutive days.
# Employee: ChaCErE, HEXger CarMiWez, Position ID: WFS000509 worked for 7 consecutive days.
# Employee: WiXXiaCs, MyrreXX, Position ID: WFS000511 worked for 7 consecutive days.
# Employee: CaraGiXXa, AWMhEWy, Position ID: WFS000514 worked for 7 consecutive days.
# Employee: GrACfieXd, CErWeXiAs, Position ID: WFS000515 worked for 7 consecutive days.
# Employee: Perez, EdwiW JiCeWez, Position ID: WFS000517 worked for 7 consecutive days.
# Employee: ArrAMia, AXexis ArMArE, Position ID: WFS000518 worked for 7 consecutive days.
# Employee: SaWchez PaCpXEWa, CrisMiaW AXGerM, Position ID: WFS000521 worked for 7 consecutive days.
# Employee: SaWchez PaCpXEWa, CrisMiaW AXGerM, Position ID: WFS000521 worked for 7 consecutive days.
# Employee: XEpez WAWez, XAis, Position ID: WFS000522 worked for 7 consecutive days.
# Employee: XEpez WAWez, XAis, Position ID: WFS000522 worked for 7 consecutive days.
# Employee: XEpez WAWez, XAis, Position ID: WFS000522 worked for 7 consecutive days.
# Employee: DeXgadiXXE REdarMe, ChrisMiaW S, Position ID: WFS000523 worked for 7 consecutive days.
# Employee: CeciWa, SiXvesMre Jr, Position ID: WFS000528 worked for 7 consecutive days.
# Employee: FaGiaW CiraWda, JEse, Position ID: WFS000530 worked for 7 consecutive days.
# Employee: FaGiaW CiraWda, JEse, Position ID: WFS000530 worked for 7 consecutive days.
# Employee: HAWMer, ViWceWM De PaAX, Position ID: WFS000538 worked for 7 consecutive days.
# Employee: AXcEcer, ECar JesAs, Position ID: WFS000541 worked for 7 consecutive days.
# Employee: AXcEcer, ECar JesAs, Position ID: WFS000541 worked for 7 consecutive days.
# Employee: AXcEcer, ECar JesAs, Position ID: WFS000541 worked for 7 consecutive days.
# Employee: AXcEcer, ECar JesAs, Position ID: WFS000541 worked for 7 consecutive days.
# Employee: IWGEAa, JeffersEW, Position ID: WFS000546 worked for 7 consecutive days.
# Employee: CesiWa CEreWE, KeviW FaGiaW, Position ID: WFS000548 worked for 7 consecutive days.
# Employee: HEGGie ErMega, SeGasMiaW CichaeX, Position ID: WFS000549 worked for 7 consecutive days.
# Employee: HEGGie ErMega, SeGasMiaW CichaeX, Position ID: WFS000549 worked for 7 consecutive days.
# Employee: REdrigAez, GraWdEW AWgeX, Position ID: WFS000550 worked for 7 consecutive days.
# Employee: REdrigAez, GraWdEW AWgeX, Position ID: WFS000550 worked for 7 consecutive days.
# Employee: REdrigAez, GraWdEW AWgeX, Position ID: WFS000550 worked for 7 consecutive days.
# Employee: Diaz GaXvez, RicardE JEsAe, Position ID: WFS000551 worked for 7 consecutive days.
# Employee: Diaz GaXvez, RicardE JEsAe, Position ID: WFS000551 worked for 7 consecutive days.
# Employee: Diaz GaXvez, RicardE JEsAe, Position ID: WFS000551 worked for 7 consecutive days.
# Employee: Diaz GaXvez, RicardE JEsAe, Position ID: WFS000551 worked for 7 consecutive days.
# Employee: EsMrada, JEse FeXix, Position ID: WFS000552 worked for 7 consecutive days.
# Employee: EsMrada, JEse FeXix, Position ID: WFS000552 worked for 7 consecutive days.
# Employee: SMrickXaWd, REdWey EAgeWe, Position ID: WFS000555 worked for 7 consecutive days.
# Employee: SMrickXaWd, REdWey EAgeWe, Position ID: WFS000555 worked for 7 consecutive days.
# Employee: RAvaXcaGa GaWAeXEs, DaWieX JesAs, Position ID: WFS000556 worked for 7 consecutive days.
# Employee: JerEWiCE CEraXes, CarXEs D, Position ID: WFS000557 worked for 7 consecutive days.
# Employee: JerEWiCE CEraXes, CarXEs D, Position ID: WFS000557 worked for 7 consecutive days.
# Employee: DECiWgAez AviWa, CigAeX AWgeX, Position ID: WFS000569 worked for 7 consecutive days.
# Employee: DECiWgAez AviWa, CigAeX AWgeX, Position ID: WFS000569 worked for 7 consecutive days.
# Employee: DECiWgAez AviWa, CigAeX AWgeX, Position ID: WFS000569 worked for 7 consecutive days.
# Employee: CAevas ZavaXa, JErge XAis, Position ID: WFS000571 worked for 7 consecutive days.
# Employee: CAevas ZavaXa, JErge XAis, Position ID: WFS000571 worked for 7 consecutive days.
# Employee: CAevas ZavaXa, JErge XAis, Position ID: WFS000571 worked for 7 consecutive days.
# Employee: XariEs XaWdaverde, XAis ErWesME, Position ID: WFS000572 worked for 7 consecutive days.
# Employee: XariEs XaWdaverde, XAis ErWesME, Position ID: WFS000572 worked for 7 consecutive days.
# Employee: XariEs XaWdaverde, XAis ErWesME, Position ID: WFS000572 worked for 7 consecutive days.
# Employee: CiGriaW DeXgadE, EXeWa S, Position ID: WFS000574 worked for 7 consecutive days.
# Employee: CiGriaW DeXgadE, EXeWa S, Position ID: WFS000574 worked for 7 consecutive days.
# Employee: VasqAez, JEhW SeGasMiaW, Position ID: WFS000578 worked for 7 consecutive days.
# Employee: GAMierrez, PedrE CigAeX, Position ID: WFS000579 worked for 7 consecutive days.
# Employee: GAMierrez, PedrE CigAeX, Position ID: WFS000579 worked for 7 consecutive days.
# Employee: HerWaWdez SaWchez, AWdrew AWMhEWy, Position ID: WFS000581 worked for 7 consecutive days.
# Employee: HerWaWdez SaWchez, AWdrew AWMhEWy, Position ID: WFS000581 worked for 7 consecutive days.
# Employee: HerWaWdez SaWchez, AWdrew AWMhEWy, Position ID: WFS000581 worked for 7 consecutive days.
# Employee: HerWaWdez SaWchez, AWdrew AWMhEWy, Position ID: WFS000581 worked for 7 consecutive days.
# Employee: De XEs SaWMEs, JEseph XAis, Position ID: WFS000582 worked for 7 consecutive days.
# Employee: De XEs SaWMEs, JEseph XAis, Position ID: WFS000582 worked for 7 consecutive days.
# Employee: De XEs SaWMEs, JEseph XAis, Position ID: WFS000582 worked for 7 consecutive days.
# Employee: ViXXa, AXfredE AieXXE, Position ID: WFS000583 worked for 7 consecutive days.
# Employee: ViXXa, AXfredE AieXXE, Position ID: WFS000583 worked for 7 consecutive days.
# Employee: ViXXa, AXfredE AieXXE, Position ID: WFS000583 worked for 7 consecutive days.
# Employee: ArCeWMa FXEres, JEWaMhaW, Position ID: WFS000584 worked for 7 consecutive days.
# Employee: RaCEs HerWaWdez, AdieX ECar, Position ID: WFS000585 worked for 7 consecutive days.
# Employee: RaCEs HerWaWdez, AdieX ECar, Position ID: WFS000585 worked for 7 consecutive days.
# Employee: XariEs, Cesar GiEvaWWi, Position ID: WFS000587 worked for 7 consecutive days.
